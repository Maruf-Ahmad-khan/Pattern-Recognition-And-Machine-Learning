# %%
import numpy as np
import seaborn  as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import warnings 
warnings.filterwarnings('ignore')
data = pd.read_excel('Consolidated data 26 to 30 Sept.xlsx')
data.shape
# Out:
# (116, 6)

# %%
data.head()
# Out:
#                                  Campaign_Name Sub_Id  Total_Payout  \
# 0  Flipkart [CPS] IN - Influencer Partnerships    aab           907
# 1  Flipkart [CPS] IN - Influencer Partnerships    app            14
# 2  Flipkart [CPS] IN - Influencer Partnerships    app             3
# 3  Flipkart [CPS] IN - Influencer Partnerships    app           100
# 4  Flipkart [CPS] IN - Influencer Partnerships    app            36
#
#    Total_Sales_Count       Date  Partner
# 0                 14 2024-09-26  Admitad
# 1                  2 2024-09-26  Admitad
# 2                  1 2024-09-26  Admitad
# 3                  1 2024-09-26  Admitad
# 4                  1 2024-09-26  Admitad

# %%
Ans = data.query("Date == '2024-09-26'")
Ans.query("Sub_Id == 'app'")
# Out:
#                                   Campaign_Name Sub_Id  Total_Payout  \
# 1   Flipkart [CPS] IN - Influencer Partnerships    app            14
# 2   Flipkart [CPS] IN - Influencer Partnerships    app             3
# 3   Flipkart [CPS] IN - Influencer Partnerships    app           100
# 4   Flipkart [CPS] IN - Influencer Partnerships    app            36
# 5   Flipkart [CPS] IN - Influencer Partnerships    app            17
# 6   Flipkart [CPS] IN - Influencer Partnerships    app            16
# 7   Flipkart [CPS] IN - Influencer Partnerships    app            62
# 8   Flipkart [CPS] IN - Influencer Partnerships    app            13
# 9   Flipkart [CPS] IN - Influencer Partnerships    app            30
# 10  Flipkart [CPS] IN - Influencer Partnerships    app          7802
# 11  Flipkart [CPS] IN - Influencer Partnerships    app           706
# 23                              Myntra [CPS] IN    app            23
# 24                              Myntra [CPS] IN    app           504
# ...

# %%
Ans.query("Sub_Id == 'store'")
# Out:
#                                   Campaign_Name Sub_Id  Total_Payout  \
# 17  Flipkart [CPS] IN - Influencer Partnerships  store         15360
# 41                                         Ajio  store          2923
# 42                                         Boat  store           101
# 43                                    Tata Cliq  store            37
#
#     Total_Sales_Count       Date   Partner
# 17                448 2024-09-26   Admitad
# 41                 22 2024-09-26  Cuelinks
# 42                  1 2024-09-26  Cuelinks
# 43                  1 2024-09-26  Cuelinks

# %%
data['Date'] = pd.to_datetime(data['Date'], errors = 'coerce')

# %%
data.to_excel("Consolidated_26th_30th_data.xlsx", index=False)
